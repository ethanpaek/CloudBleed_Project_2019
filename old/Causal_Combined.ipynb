# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

COMBINED_TABLES_PATH = "./data/Combined Tables.xlsx"
FRIENDLY_NAMES = ["date", "company", "breach_type", "org_type", "num_records", "desc", "info_src", "url"]
combined_df = pd.read_excel(COMBINED_TABLES_PATH, names= FRIENDLY_NAMES, skiprows=[0])
#Samples n=10 random rows
combined_df.sample(n=10, random_state=1)
# Out:
#                  date                               company    breach_type  \
# 584              2015                              TalkTalk         hacked
# 262  October 25, 2018                          Bankers life           UNKN
# 159    March 30, 2018                                 Bezop           DISC
# 402              2007                          TK / TJ Maxx         hacked
# 521              2013                University of Delaware         hacked
# 697              2019  First American Financial Corporation  poor security
# 567              2015                             Twitch.tv         hacked
# 305     March 6, 2019                         Maffi Clinics           HACK
# 479              2011             Sony Online Entertainment         hacked
# 419              2008           Chile Ministry Of Education         hacked
#
#        org_type  num_records  \
# 584    telecoms       157000
# 262        UNKN       799563
# 159         BSF        25000
# ...

# %%
print(combined_df.breach_type.unique())
# Out:
# ['HACK' 'DISC' 'PHYS' 'INSD' 'CARD' 'UNKN' 'inside job' 'lost device '
#  'hacked' 'oops!' 'poor security']

# %% [markdown]
# #### Breach Codes across datasets
# | Description           |  PRC |  BRC                 |
# |-----------------------|------|----------------------|
# | Hacking or Malware    | HACK | hacked               |
# | Insider               | INSD | insider              |
# | Payment Card Fraud    | CARD |                      |
# | Physical Loss         | PHYS | lost device          |
# | Unintended Disclosure | DISC | oops!, poor security |
# | Unknown               | UNKN |                      |
#
# We need more contextual information, especially when cause is vague (e.g.: "hacked"). These are rough equivalents.
#
# `TODO`  Analyze text data ('desc') to augment breach type info.

# %%
org_types = print(combined_df.org_type.unique())
# Out:
# ['GOV' 'BSO' 'MED' 'EDU' 'BSF' 'BSR' 'UNKN' 'NGO' 'web' 'financial'
#  'government, military' 'telecoms' 'tech, retail' 'government' 'retail'
#  'academic' 'energy' 'military' 'web, gaming' 'healthcare'
#  'government, healthcare' 'gaming' 'media' 'military, healthcare'
#  'tech, web' 'web, military' 'web, tech' 'tech' 'transport' 'tech, app'
#  'app' 'legal']
