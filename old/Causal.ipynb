# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
#read files
pr = pd.read_csv('./data/prc.csv')
br = pd.read_csv('./data/brc.csv')

# %%
# Displays Privacy Rights Dataset
pr[0:10]
# Out:
#     Date Made Public                                     Company  \
# 0    October 7, 2015                                     LoopPay
# 1  September 1, 2016        New York State Psychiatric Institute
# 2    January 8, 2017   E-Sports Entertainment Association (ESEA)
# 3   January 10, 2017  Legal Aid Society of Orange County (LASOC)
# 4    January 3, 2017                       MetroPlus Health Plan
# 5    January 9, 2017                       Kevin Harrington, CPA
# 6   January 12, 2017                              SwimOutlet.com
# 7   January 13, 2017          Children's Hospital of Los Angeles
# 8   January 19, 2017              CoPilot Provider Services Inc.
# 9   January 20, 2017      Wonderful Center for Health Innovation
#
#              City          State Type of breach Type of organization  \
# 0          Woburn  Massachusetts           HACK                  BSO
# 1        New York       New York           HACK                  GOV
# 2         Cologne         Berlin           HACK                  BSO
# 3       Santa Ana     California           DISC                  NGO
# 4        New York       New York           DISC                  MED
# 5  Rancho Cordova     California           HACK                  BSF
# 6        Campbell     California           HACK                  BSO
# 7     Los Angeles     California           PORT                  MED
# 8   New Hyde Park       New York           HACK                  BSO
# 9      Lost Hills     California           PORT                  MED
#
#   Total Records                            Description of incident  \
# 0             0  "Months before its technology became the cente...
# 1        21,880  "The New York State Office of Mental Health (O...
# 2     1,503,710  "E-Sports Entertainment Association (ESEA), on...
# 3             0  "LASOC developed the I-CAN! web application, w...
# 4           808  As reported by Health and Human Services unaut...
# 5             0  "On November 11, 2016, I detected that someone...
# 6             0  "On October 31, 2016, we began investigating s...
# 7         3,600  "On December 21, 2016, we learned that a lapto...
# 8       220,000  "CoPilot maintains a particular website, www.m...
# 9             0  " On December 12, 2016, it was discovered that...
#
#             Information Source  \
# 0                        Media
# 1                        Media
# 2                        Media
# 3  California Attorney General
# 4            Government Agency
# 5  California Attorney General
# 6  California Attorney General
# 7  California Attorney General
# 8  California Attorney General
# 9  California Attorney General
#
#                                           Source URL  Year of Breach  \
# 0  https://www.nytimes.com/2015/10/08/technology/...            2017
# 1  https://healthitsecurity.com/news/ny-psychiatr...            2017
# 2  http://www.csoonline.com/article/3155397/secur...            2017
# 3                                                NaN            2017
# 4                                                NaN            2017
# 5                                                NaN            2017
# 6                                                NaN            2017
# 7                                                NaN            2017
# 8                                                NaN            2017
# 9                                                NaN            2017
#
#     Latitude   Longitude
# 0  42.479262  -71.152277
# 1  40.712784  -74.005941
# 2  50.937531    6.960279
# 3  33.765160 -117.835264
# 4  40.706783  -74.005889
# 5  38.596462 -121.268255
# 6  37.288231 -121.935698
# 7  34.052234 -118.243685
# 8  40.735102  -73.687908
# 9  35.616349 -119.694294

# %%
#Displays Balloon Race Dataset
br[0:10]
# Out:
#                         Entity  \
# 0                          AOL
# 1              Ameritrade Inc.
# 2                    Citigroup
# 3  Cardsystems Solutions Inc.
# 4                          AOL
# 5       US Dept of Vet Affairs
# 6    Automatic Data Processing
# 7                         KDDI
# 8              Hewlett Packard
# 9                  Monster.com
#
#                                     alternative name records lost  YEAR  \
# 0                                    American Online   92,000,000  2004
# 1                                      online broker      200,000  2005
# 2                                                NaN    3,900,000  2005
# 3  Third-party payment processor for Visa, Master...   40,000,000  2005
# 4                                    American Online   20,000,000  2006
# 5                                                NaN   26,500,000  2006
# 6           Business outsourcing, payrolls, benefits      125,000  2006
# 7               Japanese telecommunications operator    4,000,000  2006
# 8                                                NaN      200,000  2006
# 9                                       Jobs website    1,600,000  2007
#
#                                                story                SECTOR  \
# 0  Jun 2004. A former America Online software eng...                   web
# 1  Apr 2005. Computer backup tape containing pers...             financial
# 2  Jun 2005. Blame the messenger! A box of comput...             financial
# 3  Jun 2005. CardSystems was fingered by MasterCa...             financial
# 4  Aug 2006. Derp. AOL voluntarily released searc...                   web
# 5  Jul 2006. The Veterans Affairs Department agre...  government, military
# 6  Jul 2006. Automatic Data Processing, one of th...             financial
# 7  Jun 2006. Press report: "Tokyo police have arr...              telecoms
# 8  Mar 2006. Laptop lost/stolen containing employ...          tech, retail
# 9  Aug 2007. A trojan virus stole log-ins that we...                   web
#
#           METHOD interesting story  DATA SENSITIVITY DISPLAYED RECORDS  \
# 0     inside job               NaN                 1        92,000,000
# 1   lost device                NaN                 2               NaN
# 2   lost device                  y                 3               NaN
# 3         hacked                 y                 3               NaN
# 4          oops!                 y                 1               NaN
# 5   lost device                NaN                 2               NaN
# 6  poor security               NaN                 2               NaN
# 7         hacked                 y                 1               NaN
# 8   lost device                  y                 2               NaN
# 9         hacked                 y                 2               NaN
#
#    Unnamed: 10      source name  \
# 0          NaN              CNN
# 1          NaN              NBC
# 2          NaN         NY Times
# 3          NaN            Wired
# 4          NaN      Tech Crunch
# 5          NaN      GCN, US Gov
# 6          NaN         ABC News
# 7          NaN   Computer World
# 8          NaN  Computer Weekly
# 9          NaN         BBC News
#
#                                      1st source link  \
# 0  http://money.cnn.com/2004/06/23/technology/aol...
# 1                 http://www.nbcnews.com/id/7561268/
# 2  http://www.nytimes.com/2005/06/07/business/07d...
# 3  https://www.wired.com/2005/06/cardsystems-data...
# 4  http://techcrunch.com/2006/08/06/aol-proudly-r...
# 5  http://gcn.com/Articles/2009/02/02/VA-data-bre...
# 6  http://abcnews.go.com/Technology/story?id=2160...
# 7  http://www.computerworld.com/s/article/9001150...
# 8  https://www.computerweekly.com/news/2240076956...
# 9             http://news.bbc.co.uk/1/hi/6956349.stm
#
#                                      2nd source link
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  https://www.va.gov/oig/pubs/VAOIG-06-02238-163...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
#Shows graph comparing all types of data breach (Privacy Rights)
pr_breach = pr.loc[:, 'Type of breach']
pr_breach_count = pr_breach.value_counts()
pr_breach_index = pr_breach_count.index
plt.bar(pr_breach_index, pr_breach_count, align='center', alpha=0.5)
plt.ylabel('Occurences')
plt.show()

# %%
#Shows graph comparing all types of data breach (Balloon Race)
br_breach = br.loc[:, 'METHOD']
br_breach_count = br_breach.value_counts()
br_breach_index = br_breach_count.index
plt.bar(br_breach_index, br_breach_count, align='center', alpha=0.5)
plt.ylabel('Occurences')
plt.show()

# %%
#Shows graph of organization types for each hacked data breach (Privacy Rights)

pr_hacked = pr.loc[pr['Type of breach'] == 'HACK']
pr_type_count = pr_hacked.loc[:, 'Type of organization'].value_counts()
pr_type_index = pr_type_count.index
plt.bar(pr_type_index, pr_type_count, align='center', alpha=0.5)
plt.show()

# %%
#Shows graph of organization types for each hacked data breach (Balloon Race)
br_hacked = br.loc[br['METHOD'] == 'hacked']
br_type_count = br_hacked.loc[:, 'SECTOR'].value_counts()
br_type_index = br_type_count.index.tolist()
br_pos = [i for i, _ in enumerate(br_type_index)]
plt.barh(br_pos, br_type_count, align='center', alpha=0.5)
plt.yticks(br_pos, br_type_index)
plt.show()

# %%
pr_story = pr.loc[:, 'Description of incident'].astype(str)
br_story = br.loc[:, 'story'].astype(str)
br_interesting = br.loc[br['interesting story'] == 'y'].loc[:,'story'] #Only those marked with interesting story

story_total = pd.concat([pr_story, br_story],ignore_index=True)
print(story_total[0])
for story in story_total:
    if(story[0] == '"'):
        story[1:len(story)-1]
# Out:
# "Months before its technology became the centerpiece of Samsung’s new mobile payment system, LoopPay, a small Massachusetts subsidiary of the South Korean electronics giant, was the target of a sophisticated attack by a group of government-affiliated Chinese hackers.As early as March, the hackers — alternatively known as the Codoso Group or Sunshock Group by those who track them — had breached the computer network of LoopPay, a start-up in Burlington, Mass., that was acquired by Samsung in February for more than $250 million, according to several people briefed on the still-unfolding investigation, as well as Samsung and LoopPay executives."

# %%
all_text = " ".join(story for story in story_total)
wordcloud = WordCloud().generate(all_text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
