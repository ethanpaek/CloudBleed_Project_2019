# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

COMBINED_TABLES_PATH = "./data/Combined Tables.xlsx"
FRIENDLY_NAMES = ["date", "company", "breach_type", "org_type", "num_records", "desc", "info_src", "url"]
cc = pd.read_excel(COMBINED_TABLES_PATH, names= FRIENDLY_NAMES, skiprows=[0])
#Samples n=10 random rows
cc.sample(n=10, random_state=1)
# Out:
#                  date                               company    breach_type  \
# 584              2015                              TalkTalk         hacked
# 262  October 25, 2018                          Bankers life           UNKN
# 159    March 30, 2018                                 Bezop           DISC
# 402              2007                          TK / TJ Maxx         hacked
# 521              2013                University of Delaware         hacked
# 697              2019  First American Financial Corporation  poor security
# 567              2015                             Twitch.tv         hacked
# 305     March 6, 2019                         Maffi Clinics           HACK
# 479              2011             Sony Online Entertainment         hacked
# 419              2008           Chile Ministry Of Education         hacked
#
#        org_type  num_records  \
# 584    telecoms       157000
# 262        UNKN       799563
# 159         BSF        25000
# ...

# %%
print(set(cc['breach_type']))
# Out:
# {'inside job', 'oops!', 'UNKN', 'poor security', 'lost device ', 'INSD', 'CARD', 'hacked', 'DISC', 'HACK', 'PHYS'}

# %% [markdown]
# ##### PRC Codes:
#     HACK: Hacking or Malware
#     INSD: Insider
#     CARD: Payment Card Fraud
#     PHYS: Physical Loss
#     PORT: Portable Device
#     STAT: Stationary Device
#     DISC: Unintended Disclosure
#     UNKN: Unknown
#
# ###### TODO: Combine w/ BRC Breach Types

# %%
print(set(cc['org_type']))
# Out:
# {'BSR', 'UNKN', 'telecoms', 'military, healthcare', 'energy', 'EDU', 'GOV', 'government, healthcare', 'app', 'government', 'BSO', 'gaming', 'legal', 'tech, retail', 'tech', 'academic', 'financial', 'retail', 'BSF', 'tech, app', 'MED', 'web, tech', 'media', 'military', 'NGO', 'web, military', 'government, military', 'transport', 'web', 'web, gaming', 'tech, web', 'healthcare'}
